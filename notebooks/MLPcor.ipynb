# %% [markdown]
# # Perceptron et MLP

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Fonctions d'activations et leurs dérivées
# Commencons par définir et tracer quelques fonctions d'activations ainsi que leurs dérivées. Ces fonctions pernnent entrée un vecteur numpy et retourne un vecteur numpy.

# %% [markdown]
# ### Fonction sigmoid
# La fonction sigmoid est données par $\Phi(x)=\frac{1}{1+\exp(-x)}$.

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %% [markdown]
# Cette fonction ressemble à une rampe douce :

# %%
x = np.linspace(-5,5)
f=plt.plot(x,sigmoid(x))

# %% [markdown]
# La dérivée de celle ci est donc :
# $$
# \begin{align}
# \Phi'(x) &= \frac{\exp(-x)}{(1+\exp(-x))^2}\\
# &=\frac{1}{(1+\exp(-x))}\frac{\exp(-x)}{(1+\exp(-x))}\\
# &=\Phi(x)(1-\Phi(x))
# \end{align}
# $$
# ### Question
# coder la fonction der_sigmoid(x) qui clacul la dérivée de la fonction sigmoid en un point x. Cette fonction prend entrée un vecteur numpy et retourne un vecteur numpy. Observer son évolution.

# %%
def der_sigmoid(x):
    return sigmoid(x)*(1-sigmoid(x))

# %%
f=plt.plot(x,der_sigmoid(x))

# %% [markdown]
# ### Fonction tanh
# Faisons de même pour la fonction d'activation $tanh(x)$

# %%
def tanh(x):
    return np.tanh(x)

# %%
def der_tanh(x):
    return 1-np.power(np.tanh(x),2)

# %%
f=plt.plot(x,tanh(x))

# %%
f=plt.plot(x,der_tanh(x))

# %% [markdown]
# ### Fonction Relu

# %%
def relu(x):
    v=np.zeros(x.shape)
    v[x>0]=x[x>0]
    return v

# %%
f=plt.plot(x,relu(x))

# %% [markdown]
# ### Question
# Coder une focntion calulant la dérivée de la fonction relu et tracer sa courbe entre $[-5,5]$

# %%
def der_relu(x):
    v=np.zeros(x.shape)
    v[x>0]=1
    return v

# %%
f=plt.plot(der_relu(x))

# %% [markdown]
# ## Fonction de cout
# Définissons la fonction de cout de cross entropy pour la classification binaire. Cette fonction prend deux arguments la valeur prédite $\tilde{y}\in[0,1]$ et la vraie valeure $y\in\{0,1\}$ et mesure l'écart.
# $$L(\tilde{y},y)=-y\log(\tilde(y))-(1-y)\log(1-\tilde{y})$$
# Pour éviter les problème numérique nous capeerons les valeurs de $\tilde{y}$.

# %%
def cross_entropy(yh,y):
    th = 0.000001
    yh[yh<th] = th
    yh[yh>(1-th)] = 1-th
    return -y*np.log(yh)-(1-y)*np.log(1-yh)

# %% [markdown]
# ### Questions
# Ecrire une foncion python qui calcul $\frac{\delta L'(\tilde{y},y)}{\delta\tilde{y}}$. Caper également les valeur de $\tilde{y}$.

# %%
def der_cross_entropy(yh,y):
    th= 0.000001
    yh[yh<th] = th
    yh[yh>(1-th)] = 1-th
    return -y/yh+(1-y)/(1-yh)

# %% [markdown]
# ## Perceptrons
# Commencons par nous créer un jeu de données de test en 2 dimension.

# %%
X = np.concatenate([np.random.normal([-5,-5],size=[100,2]),
                    np.random.normal([-5,5],size=[100,2]),
                    np.random.normal([5,-5],size=[100,2]),
                    np.random.normal([5,5],size=[100,2])])
y = np.concatenate([np.ones(200),np.zeros(200)])

# %%
f= plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# Voici maintenant le squelette d'une classe python qui imlémente un perceptron.

# %%
class Perceptron():
    # inialisation
    def __init__(self,input_size):
        # taille des entrées
        self.input_size = input_size
        # vecteur de poids de taille d,1
        self.w = np.random.normal(size=(self.input_size,1))
    
    # calcul de la sortie
    def forward(self,X):
        # multiplication matricielle
        z = np.matmul(X,self.w)
        # fonction d'activation sigmoide
        yh = sigmoid(z)
        # remise en forme vectorielle
        return yh.reshape((X.shape[0],))
    
    # calcul du gradient pour un semble de données X de taille N,d et y de taille N 
    def backward(self,X,y):
        # calcul des sorties
        yh = self.forward(X)
        # dérivée de la fonction de cout
        dce  = der_cross_entropy(yh,y)
        # dérivée de la fonction d'activation
        dact = der_sigmoid(yh)
        # produit des deux de taille N,1
        eta = np.reshape(dce*dact,(X.shape[0],1))
        # repetitions pour obtennir une matrice N,d
        Eta = np.repeat(eta,repeats=self.input_size,axis=1)
        # calcul du gradient : moyenne des eta*X
        G = np.mean(Eta*X,axis=0)
        # mise dans le bon sens
        return np.reshape(G,(self.input_size,1))
    
    # descente de gradient
    # step_size : pas du gradient
    def grad_desc(self,X,y,step_size):
        # calcul du gradient
        grad = self.backward(X,y)
        # descente mise a jour des poids
        self.w = self.w - step_size*grad
    
    # apprentissage batch
    # epoch : nombre de balyage du jeu de données 
    def train_batch(self,X,y,step_size,epoch):
        # vecteur permettant de stocker l'évolution de l'erreur
        hist = [self.loss(X,y)]
        # pour un nombre d'epoque données
        for r in range(0,epoch):
            # descente de gradient
            self.grad_desc(X,y,step_size)
            # calcul de la fonction de cout
            l=self.loss(X,y)
            # diminution du pas si nécessaire
            if(l>hist[-1]):
                step_size=step_size*0.5
            #print("Loss : {}".format(l))
            hist.append(l)
        return np.array(hist)
        
    # apprentissage sgd 
    # batch_size : taille des batchs
    def train_sgd(self,X,y,step_size,epoch,batch_size):
        # vecteur permettant de stocker l'évolution de l'erreur
        hist = [self.loss(X,y)]
        # combien de batch complés peut on faire 
        nb_batchs = np.floor(X.shape[0]/batch_size)
        # pour chaque balayage
        for r in range(0,epoch):
            # permuation aléatoire du jeu de données
            perm = np.random.permutation(X.shape[0])
            # pour chaque batch
            for b in range(0,int(nb_batchs)):
                # recupérations des indices des lignes composant le batch
                c_batch= perm[range(b*batch_size,(b+1)*batch_size)]
                # descente de gradient surle batch
                self.grad_desc(X[c_batch,:],y[c_batch],step_size)
            # calcul de l'erreur
            l=self.loss(X,y)
            #print("Loss : {}".format(l))
            hist.append(l)
        return np.array(hist)
    
    # fonction de cout
    def loss(self,X,y):
        yh = self.forward(X)
        L = cross_entropy(yh,y)
        return np.mean(L)

# %% [markdown]
# ### Usage
# Aprés avoir lu attentivement le code nous pouvons tester notre perceptrons sur les données d'exemple.

# %%
# creation d'un perceptrons
per = Perceptron(2)
# prediction
yh  = per.forward(X)
# valeur initiale de la fonction de cout
print("Loss : {}".format(per.loss(X,y)))
# Out:
# Loss : 7.894997664176876

# %% [markdown]
# Essayons de faire un balayage et calculons la nouvelle valeur de l'erreur.

# %%
per.train_batch(X,y,0.0001,1)
print("Loss : {}".format(per.loss(X,y)))
# Out:
# Loss : 3.0857559355811315
# /home/eetie/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %% [markdown]
# Avant de faire plusieur passe et d'observer l'évolution de la fonction de cout.

# %%
per = Perceptron(2)
h = per.train_batch(X,y,0.01,500)
f=plt.plot(h)

# %% [markdown]
# Nous pouvons aussi visualiser les predictions du perceptrons.

# %%
f=plt.scatter(X[:,0],X[:,1],c=per.forward(X)>0.5)

# %% [markdown]
# Essayons avec un autre jeu de données :

# %%
X1=np.concatenate([-1*np.random.rand(200,1)-0.5,np.random.rand(200,1)],axis=1)
X2=np.concatenate([np.random.rand(200,1),np.random.rand(200,1)],axis=1)
X=np.matmul(np.concatenate([X1,X2]),np.reshape([3,0.7,3,2.8],(2,2)))
y=np.concatenate([np.ones(200),np.zeros(200)])
f=plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# ### Questions
#
# - Créer un matrice numpy qui contient X et une colonne de 1 supplémentaire, cela permettra de prendre en compte le biais dans l'appentissage.
# - Créer ensuite un perceptron de taille 3
# - Faire un apprentissage batch de 200 époques avec un pas de 0.05 initialement.
# - Visualiser les résultats
# - Faites varier les paramètres nombre d'époques et pas de gradient

# %%
Xb=np.concatenate([X,np.ones((400,1))],axis=1)
per = Perceptron(3)
h = per.train_batch(Xb,y,0.05,200)
f=plt.plot(h)

# %%
f=plt.scatter(X[:,0],X[:,1],c=per.forward(Xb)>0.5)

# %% [markdown]
# # Questions
#
# - Créer une methode train_sgd dans la classe perceptrons. cette méthode prend en entrée X,y, le pas du gradient, le nombre d'époque et la taille des batchs. Pour chaque époque elle mélange le jeux de données (np.random.permutation) et mets a jour les poids après chaque batchs.
# - Tester la avec le code suivant.
# - Faites varier les paramètres.
# - Comparer avec l'apprentissage batch.

# %%
Xb=np.concatenate([X,np.ones((400,1))],axis=1)
per = Perceptron(3)
h = per.train_sgd(Xb,y,0.05,200,20)
f=plt.plot(h)

# %%
f=plt.scatter(X[:,0],X[:,1],c=per.forward(Xb)>0.5)

# %% [markdown]
# ## MLP

# %% [markdown]
# Regardons maintenant un jeu de données un tout petit peu plus compliqué

# %%
X = np.concatenate([np.random.normal([-5,-5],size=[100,2]),
                    np.random.normal([5,5],size=[100,2]),
                    np.random.normal([5,-5],size=[100,2]),
                    np.random.normal([-5,5],size=[100,2])])
y = np.concatenate([np.ones(200),np.zeros(200)])

# %%
f=plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# ### Questions
# - Créer un perceptrons pour ces données avec biais et sans biais
# - Essayez de faire l'apprentissage pas de 0.001, 100 époques et batch de tailles 20
# - visualissez les résultats
# - Que remarquer vous ?

# %%
per = Perceptron(3)
Xb = np.concatenate([X,np.ones((X.shape[0],1))],axis=1) 
h=per.train_sgd(Xb,y,0.001,200,10)
f=plt.plot(h)

# %%
f=plt.scatter(X[:,0],X[:,1],c=per.forward(Xb))

# %% [markdown]
# ### Questions
#
# - Créer un MLP avec keras pour résoudre ce problème avec 1 couche caché et activation relu.
# - Voir la documentation de keras.layers.Input,Dense et keras.models.Model et keras.utils.to_categorical
# - Utiliser les méthodes compile, fit et predict
# - la derniere couche doit être une couche softmax avec deux sorties et y doit être recodée en une matrice binaire N,2
# - Faire varier les paramètres et observer

# %%
# definition d'un mlp avec keras
from keras.layers import Layer,Input, Dense
from keras.models import Model


inputs = Input(shape=(X.shape[1],)) 

hidden = Dense(32,activation='relu')(inputs)

outputs = Dense(2, activation='softmax')(hidden)

mlp = Model(inputs,outputs)
# Out:
# Using TensorFlow backend.

# %%
mlp.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
from keras.utils import to_categorical
y_bin = to_categorical(y)

# %%
hist = mlp.fit(X,y_bin,batch_size=20,epochs=100)
# Out:
# Epoch 1/100
# 400/400 [==============================] - 0s 768us/step - loss: 1.1342 - acc: 0.4400
# Epoch 2/100
# 400/400 [==============================] - 0s 90us/step - loss: 0.6885 - acc: 0.5675
# Epoch 3/100
# 400/400 [==============================] - 0s 81us/step - loss: 0.4153 - acc: 0.8175
# Epoch 4/100
# 400/400 [==============================] - 0s 76us/step - loss: 0.2587 - acc: 0.9875
# Epoch 5/100
# 400/400 [==============================] - 0s 71us/step - loss: 0.1741 - acc: 1.0000
# Epoch 6/100
# 400/400 [==============================] - 0s 92us/step - loss: 0.1253 - acc: 1.0000
# Epoch 7/100
# 400/400 [==============================] - 0s 85us/step - loss: 0.0945 - acc: 1.0000
# Epoch 8/100
# 400/400 [==============================] - 0s 83us/step - loss: 0.0740 - acc: 1.0000
# Epoch 9/100
# 400/400 [==============================] - 0s 88us/step - loss: 0.0596 - acc: 1.0000
# Epoch 10/100
# 400/400 [==============================] - 0s 60us/step - loss: 0.0490 - acc: 1.0000
# Epoch 11/100
# 400/400 [==============================] - 0s 64us/step - loss: 0.0412 - acc: 1.0000
# Epoch 12/100
# 400/400 [==============================] - 0s 99us/step - loss: 0.0351 - acc: 1.0000
# Epoch 13/100
# 400/400 [==============================] - 0s 77us/step - loss: 0.0304 - acc: 1.0000
# Epoch 14/100
# 400/400 [==============================] - 0s 84us/step - loss: 0.0265 - acc: 1.0000
# Epoch 15/100
# 400/400 [==============================] - 0s 87us/step - loss: 0.0234 - acc: 1.0000
# Epoch 16/100
# 400/400 [==============================] - 0s 99us/step - loss: 0.0208 - acc: 1.0000
# Epoch 17/100
# 400/400 [==============================] - 0s 66us/step - loss: 0.0186 - acc: 1.0000
# Epoch 18/100
# 400/400 [==============================] - 0s 84us/step - loss: 0.0167 - acc: 1.0000
# Epoch 19/100
# 400/400 [==============================] - 0s 74us/step - loss: 0.0151 - acc: 1.0000
# Epoch 20/100
# 400/400 [==============================] - 0s 75us/step - loss: 0.0138 - acc: 1.0000
# Epoch 21/100
# 400/400 [==============================] - 0s 73us/step - loss: 0.0126 - acc: 1.0000
# Epoch 22/100
# 400/400 [==============================] - 0s 76us/step - loss: 0.0116 - acc: 1.0000
# Epoch 23/100
# 400/400 [==============================] - 0s 118us/step - loss: 0.0107 - acc: 1.0000
# Epoch 24/100
# 400/400 [==============================] - 0s 70us/step - loss: 0.0099 - acc: 1.0000
# Epoch 25/100
# 400/400 [==============================] - 0s 69us/step - loss: 0.0091 - acc: 1.0000
# Epoch 26/100
# 400/400 [==============================] - 0s 95us/step - loss: 0.0085 - acc: 1.0000
# Epoch 27/100
# 400/400 [==============================] - 0s 95us/step - loss: 0.0079 - acc: 1.0000
# Epoch 28/100
# 400/400 [==============================] - 0s 77us/step - loss: 0.0074 - acc: 1.0000
# Epoch 29/100
# 400/400 [==============================] - 0s 89us/step - loss: 0.0070 - acc: 1.0000
# Epoch 30/100
# 400/400 [==============================] - 0s 102us/step - loss: 0.0065 - acc: 1.0000
# Epoch 31/100
# 400/400 [==============================] - 0s 106us/step - loss: 0.0061 - acc: 1.0000
# Epoch 32/100
# 400/400 [==============================] - 0s 92us/step - loss: 0.0058 - acc: 1.0000
# Epoch 33/100
# 400/400 [==============================] - 0s 85us/step - loss: 0.0055 - acc: 1.0000
# Epoch 34/100
# 400/400 [==============================] - 0s 98us/step - loss: 0.0052 - acc: 1.0000
# Epoch 35/100
# 400/400 [==============================] - 0s 82us/step - loss: 0.0049 - acc: 1.0000
# Epoch 36/100
# 400/400 [==============================] - 0s 90us/step - loss: 0.0047 - acc: 1.0000
# Epoch 37/100
# 400/400 [==============================] - 0s 101us/step - loss: 0.0044 - acc: 1.0000
# Epoch 38/100
# 400/400 [==============================] - 0s 86us/step - loss: 0.0042 - acc: 1.0000
# Epoch 39/100
# 400/400 [==============================] - 0s 93us/step - loss: 0.0040 - acc: 1.0000
# Epoch 40/100
# 400/400 [==============================] - 0s 105us/step - loss: 0.0038 - acc: 1.0000
# Epoch 41/100
# 400/400 [==============================] - 0s 107us/step - loss: 0.0037 - acc: 1.0000
# Epoch 42/100
# 400/400 [==============================] - 0s 104us/step - loss: 0.0035 - acc: 1.0000
# Epoch 43/100
# 400/400 [==============================] - 0s 108us/step - loss: 0.0033 - acc: 1.0000
# Epoch 44/100
# 400/400 [==============================] - 0s 113us/step - loss: 0.0032 - acc: 1.0000
# Epoch 45/100
# 400/400 [==============================] - 0s 84us/step - loss: 0.0031 - acc: 1.0000
# Epoch 46/100
# 400/400 [==============================] - 0s 93us/step - loss: 0.0029 - acc: 1.0000
# Epoch 47/100
# 400/400 [==============================] - 0s 81us/step - loss: 0.0028 - acc: 1.0000
# Epoch 48/100
# 400/400 [==============================] - 0s 97us/step - loss: 0.0027 - acc: 1.0000
# Epoch 49/100
# 400/400 [==============================] - 0s 112us/step - loss: 0.0026 - acc: 1.0000
# Epoch 50/100
# 400/400 [==============================] - 0s 79us/step - loss: 0.0025 - acc: 1.0000
# Epoch 51/100
# 400/400 [==============================] - 0s 136us/step - loss: 0.0024 - acc: 1.0000
# Epoch 52/100
# 400/400 [==============================] - 0s 114us/step - loss: 0.0023 - acc: 1.0000
# Epoch 53/100
# 400/400 [==============================] - 0s 95us/step - loss: 0.0022 - acc: 1.0000
# Epoch 54/100
# 400/400 [==============================] - 0s 107us/step - loss: 0.0022 - acc: 1.0000
# Epoch 55/100
# 400/400 [==============================] - 0s 105us/step - loss: 0.0021 - acc: 1.0000
# Epoch 56/100
# 400/400 [==============================] - 0s 81us/step - loss: 0.0020 - acc: 1.0000
# Epoch 57/100
# 400/400 [==============================] - 0s 91us/step - loss: 0.0020 - acc: 1.0000
# Epoch 58/100
# 400/400 [==============================] - 0s 106us/step - loss: 0.0019 - acc: 1.0000
# Epoch 59/100
# 400/400 [==============================] - 0s 86us/step - loss: 0.0018 - acc: 1.0000
# Epoch 60/100
# 400/400 [==============================] - 0s 79us/step - loss: 0.0018 - acc: 1.0000
# Epoch 61/100
# 400/400 [==============================] - 0s 74us/step - loss: 0.0017 - acc: 1.0000
# Epoch 62/100
# 400/400 [==============================] - 0s 114us/step - loss: 0.0017 - acc: 1.0000
# Epoch 63/100
# 400/400 [==============================] - 0s 99us/step - loss: 0.0016 - acc: 1.0000
# Epoch 64/100
# 400/400 [==============================] - 0s 100us/step - loss: 0.0016 - acc: 1.0000
# Epoch 65/100
# 400/400 [==============================] - 0s 110us/step - loss: 0.0015 - acc: 1.0000
# Epoch 66/100
# 400/400 [==============================] - 0s 83us/step - loss: 0.0015 - acc: 1.0000
# Epoch 67/100
# 400/400 [==============================] - 0s 93us/step - loss: 0.0014 - acc: 1.0000
# Epoch 68/100
# 400/400 [==============================] - 0s 85us/step - loss: 0.0014 - acc: 1.0000
# Epoch 69/100
# 400/400 [==============================] - 0s 76us/step - loss: 0.0013 - acc: 1.0000
# Epoch 70/100
# 400/400 [==============================] - 0s 114us/step - loss: 0.0013 - acc: 1.0000
# Epoch 71/100
# 400/400 [==============================] - 0s 86us/step - loss: 0.0013 - acc: 1.0000
# Epoch 72/100
# 400/400 [==============================] - 0s 89us/step - loss: 0.0012 - acc: 1.0000
# Epoch 73/100
# 400/400 [==============================] - 0s 108us/step - loss: 0.0012 - acc: 1.0000
# Epoch 74/100
# 400/400 [==============================] - 0s 98us/step - loss: 0.0012 - acc: 1.0000
# Epoch 75/100
# 400/400 [==============================] - 0s 77us/step - loss: 0.0011 - acc: 1.0000
# Epoch 76/100
# 400/400 [==============================] - 0s 78us/step - loss: 0.0011 - acc: 1.0000
# Epoch 77/100
# 400/400 [==============================] - 0s 76us/step - loss: 0.0011 - acc: 1.0000
# Epoch 78/100
# 400/400 [==============================] - 0s 70us/step - loss: 0.0011 - acc: 1.0000
# Epoch 79/100
# 400/400 [==============================] - 0s 67us/step - loss: 0.0010 - acc: 1.0000
# Epoch 80/100
# 400/400 [==============================] - 0s 95us/step - loss: 9.9808e-04 - acc: 1.0000
# Epoch 81/100
# 400/400 [==============================] - 0s 72us/step - loss: 9.7311e-04 - acc: 1.0000
# Epoch 82/100
# 400/400 [==============================] - 0s 81us/step - loss: 9.4889e-04 - acc: 1.0000
# Epoch 83/100
# 400/400 [==============================] - 0s 83us/step - loss: 9.2540e-04 - acc: 1.0000
# Epoch 84/100
# 400/400 [==============================] - 0s 80us/step - loss: 9.0347e-04 - acc: 1.0000
# Epoch 85/100
# 400/400 [==============================] - 0s 84us/step - loss: 8.8140e-04 - acc: 1.0000
# Epoch 86/100
# 400/400 [==============================] - 0s 75us/step - loss: 8.6002e-04 - acc: 1.0000
# Epoch 87/100
# 400/400 [==============================] - 0s 82us/step - loss: 8.4058e-04 - acc: 1.0000
# Epoch 88/100
# 400/400 [==============================] - 0s 77us/step - loss: 8.2034e-04 - acc: 1.0000
# Epoch 89/100
# 400/400 [==============================] - 0s 85us/step - loss: 8.0146e-04 - acc: 1.0000
# Epoch 90/100
# 400/400 [==============================] - 0s 72us/step - loss: 7.8312e-04 - acc: 1.0000
# Epoch 91/100
# 400/400 [==============================] - 0s 64us/step - loss: 7.6582e-04 - acc: 1.0000
# Epoch 92/100
# 400/400 [==============================] - 0s 74us/step - loss: 7.4818e-04 - acc: 1.0000
# Epoch 93/100
# 400/400 [==============================] - 0s 67us/step - loss: 7.3133e-04 - acc: 1.0000
# Epoch 94/100
# 400/400 [==============================] - 0s 76us/step - loss: 7.1586e-04 - acc: 1.0000
# Epoch 95/100
# 400/400 [==============================] - 0s 71us/step - loss: 6.9943e-04 - acc: 1.0000
# Epoch 96/100
# 400/400 [==============================] - 0s 78us/step - loss: 6.8443e-04 - acc: 1.0000
# Epoch 97/100
# 400/400 [==============================] - 0s 76us/step - loss: 6.6946e-04 - acc: 1.0000
# Epoch 98/100
# 400/400 [==============================] - 0s 74us/step - loss: 6.5543e-04 - acc: 1.0000
# Epoch 99/100
# 400/400 [==============================] - 0s 73us/step - loss: 6.4094e-04 - acc: 1.0000
# Epoch 100/100
# 400/400 [==============================] - 0s 70us/step - loss: 6.2807e-04 - acc: 1.0000

# %%
yh = mlp.predict(X)[:,1]>0.5
f=plt.scatter(X[:,0],X[:,1],c=yh)
